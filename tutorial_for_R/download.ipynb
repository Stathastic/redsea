# %%
os.listdir("../../dataset/")
# Out:
# ['redsea']

# %%
# Out:
# Retrieving folder list
# Retrieving folder 1O0Tn4OZmowg5rF1IZyW-t-2DX6Hk6knp Chlorophyll
# Retrieving folder 1eJMqsh_pZTqsE-qKeoCNcUzQm4wim2ot 8-Days composite
# Processing file 1fZV0ic2ZocGu6cMzIhj9fl9MVd1TLRTn Aqua_MODIS_chloA_8_Days_Composite.2003_2022.nc
# Retrieving folder 1Qvjavqry2g7HX5PaaaycysK-qDOTnyGf Daily
# Processing file 1JjCgH7NshgxPCS1hfLT4b5XKad9l-XRw Daily_Aqua_MODIS_chloA.2003_2012.nc
# Processing file 1PyLCnaMde_enhtwCJMJeR8f3lNdETGU- Daily_Aqua_MODIS_chloA.2013_2022.nc
# Retrieving folder 1xqEhqArsrw1XHHeMoTrCb2FAgd6zobey Monthly
# Processing file 1jsacqWo3Lzj9_roz8OK8_S6ma2nEZUM6 Aqua_MODIS_chloA_Monthly.2003_2022.nc
# Retrieving folder 1Lb2aGqBpCo5CZtoIviBopSvOWjdalObj K490
# Retrieving folder 1alzqvyTxB_yRssCXbZujH9pSg2o5Ah22 Aqua_MODIS_Subsetted_K490_8_Days_CompositeOver_Red_Sea_nc_files
# Processing file 1HzEVBuMLL0snM5p7Vdi8WUtqZyJvgG7W MODIS_k490.2003.nc
# Processing file 14QQIRt403aoev5U5zX5D3NcaUijOK2-j MODIS_k490.2004.nc
# ...
